# %%
# %connect_info
# Out:
# {
#   "shell_port": 49948,
#   "iopub_port": 49949,
#   "stdin_port": 49950,
#   "control_port": 49952,
#   "hb_port": 49951,
#   "ip": "127.0.0.1",
#   "key": "8c306c5c-4e4547257050ff37d65da911",
#   "transport": "tcp",
#   "signature_scheme": "hmac-sha256",
#   "kernel_name": ""
# }
#
# Paste the above JSON into a file, and connect with:
#     $> jupyter <app> --existing <file>
# or, if you are local, you can connect with just:
#     $> jupyter <app> --existing kernel-0cd3fde2-008e-4501-97e3-4561262bb2cd.json
# or even just:
#     $> jupyter <app> --existing
# if this is the most recent Jupyter kernel you have started.

# %%
# %matplotlib inline

# %%
import pandas as pd

# %%
df = pd.read_csv('data/nn_results.csv')

result_column = 'keras_info/f1_score'

# %%
df.head()
# Out:
#    Unnamed: 0  mean_accuracy  trial_id  training_iteration  time_this_iter_s  \
# 0           0       0.934701  c592d0d8                  29         26.865980
# 1           1       0.477929  c592d0d9                  22         11.126096
# 2           2       0.496160  c592d0da                  25         39.525931
# 3           3       0.500523  c592d0db                   9         19.335753
# 4           4       0.508397  c592d0dc                  22         20.409758
#
#     done  timesteps_total  episodes_total                     experiment_id  \
# 0  False              NaN             NaN  a0601c5e46a740c9ab7b38c62d56fd46
# 1  False              NaN             NaN  d3d5071ea3e74c3e9eba0a72474732b1
# 2  False              NaN             NaN  39522cdcba8a45c6b062289f7efbfc13
# 3  False              NaN             NaN  782a091e23ef4a90b9b5dcb9c7d677f1
# 4  False              NaN             NaN  8ad667290c6b4386a22577867b7672e5
#
# ...

# %%
df[[result_column, 'keras_info/weighted_support']]
# Out:
#      keras_info/f1_score  keras_info/weighted_support
# 0               0.554232                         9951
# 1               0.328687                         9951
# 2               0.328687                         9951
# 3               0.000000                         9951
# 4               0.000000                         9951
# ..                   ...                          ...
# 495             0.328687                         9951
# 496             0.000000                         9951
# 497             0.000000                         9951
# 498             0.000000                         9951
# 499             0.328687                         9951
#
# [500 rows x 2 columns]
