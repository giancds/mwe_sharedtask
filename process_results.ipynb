# %%
out = []
with open('data/tune_nn.out') as f:
    flag = False
    for line in f:
        if 'Confusion matrix:' in line:
            flag = True

        if flag:
            out.append(line)
        
        if 'weighted avg' in line:
            flag = False

# %%
out
# Out:
# ['\x1b\x1b(pid=15181)\x1b Confusion matrix:\n',
#  '\x1b\x1b(pid=15181)\x1b [[3309    0]\n',
#  '\x1b\x1b(pid=15181)\x1b  [1021    0]]\n',
#  '\x1b\x1b(pid=15181)\x1b \n',
#  '\x1b\x1b(pid=15181)\x1b \n',
#  '\x1b\x1b(pid=15181)\x1b Report\n',
#  "2020-05-29 19:03:37,973\tINFO logger.py:271 -- Removed the following hyperparameter values when logging to tensorboard: {'layer_size': 900, 'nlayers': 3}\n",
#  '\x1b\x1b(pid=15181)\x1b               precision    recall  f1-score   support\n',
#  '\x1b\x1b(pid=15181)\x1b \n',
#  '\x1b\x1b(pid=15181)\x1b            0       0.76      1.00      0.87      3309\n',
#  '\x1b\x1b(pid=15181)\x1b            1       0.00      0.00      0.00      1021\n',
#  '\x1b\x1b(pid=15181)\x1b \n',
#  '\x1b\x1b(pid=15181)\x1b     accuracy                           0.76      4330\n',
#  '\x1b\x1b(pid=15181)\x1b    macro avg       0.38      0.50      0.43      4330\n',
#  '\x1b\x1b(pid=15181)\x1b weighted avg       0.58      0.76      0.66      4330\n',
# ...
